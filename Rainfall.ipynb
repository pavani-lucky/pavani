# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Downloads/arunachal.csv")

# %%
data.describe()
# Out:
#        Unnamed: 0         YEAR         JAN         FEB         MAR  \
# count    91.00000    91.000000   90.000000   90.000000   89.000000
# mean    155.00000  1962.747253   48.598889   93.966667  154.446067
# std      26.41338    27.695003   34.687078   46.258375   87.918484
# min     110.00000  1916.000000    1.800000    6.100000   28.500000
# 25%     132.50000  1938.500000   20.075000   65.625000  101.700000
# 50%     155.00000  1964.000000   45.400000   87.600000  141.700000
# 75%     177.50000  1986.500000   65.150000  120.400000  189.600000
# max     200.00000  2009.000000  164.500000  208.500000  605.600000
#
#               APR          MAY          JUN          JUL          AUG  \
# count   91.000000    91.000000    90.000000    90.000000    91.000000
# mean   262.990110   364.651648   659.556667   711.963333   502.163736
# std    113.395773   181.095447   311.642230   356.372598   275.716730
# min     94.700000   101.800000   239.400000   233.000000   172.400000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   91 non-null     int64
#  1   SUBDIVISION  91 non-null     object
#  2   YEAR         91 non-null     int64
#  3   JAN          90 non-null     float64
#  4   FEB          90 non-null     float64
#  5   MAR          89 non-null     float64
#  6   APR          91 non-null     float64
#  7   MAY          91 non-null     float64
#  8   JUN          90 non-null     float64
#  9   JUL          90 non-null     float64
#  10  AUG          91 non-null     float64
#  11  SEP          91 non-null     float64
#  12  OCT          89 non-null     float64
#  13  NOV          89 non-null     float64
#  14  DEC          89 non-null     float64
#  15  ANNUAL       85 non-null     float64
#  16  Jan-Feb      90 non-null     float64
#  17  Mar-May      89 non-null     float64
# ...

# %%
data.groupby(['SUBDIVISION']).count()
# Out:
#                    Unnamed: 0  YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  \
# SUBDIVISION
# ARUNACHAL PRADESH          91    91   90   90   89   91   91   90   90   91
#
#                    SEP  OCT  NOV  DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# SUBDIVISION
# ARUNACHAL PRADESH   91   89   89   89      85       90       89       89
#
#                    Oct-Dec
# SUBDIVISION
# ARUNACHAL PRADESH       88

# %%
data.isna().sum()
# Out:
# Unnamed: 0     0
# SUBDIVISION    0
# YEAR           0
# JAN            1
# FEB            1
# MAR            2
# APR            0
# MAY            0
# JUN            1
# JUL            1
# AUG            0
# SEP            0
# OCT            2
# NOV            2
# DEC            2
# ANNUAL         6
# Jan-Feb        1
# Mar-May        2
# Jun-Sep        2
# Oct-Dec        3
# dtype: int64

# %%
data1=data.loc[(data.YEAR<=2010)]

# %%
data1
# Out:
#     Unnamed: 0        SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0          110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6
# 1          111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9
# 2          112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1
# 3          113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6
# 4          114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6
# ..         ...                ...   ...   ...    ...    ...    ...    ...
# 86         196  ARUNACHAL PRADESH  2005  48.4  167.6  229.5  195.3  179.8
# 87         197  ARUNACHAL PRADESH  2006   6.0  103.7   63.3  202.7  321.7
# 88         198  ARUNACHAL PRADESH  2007  13.4   97.4   48.1  292.4  250.4
# 89         199  ARUNACHAL PRADESH  2008  76.7   39.7  122.6  192.4  185.0
# 90         200  ARUNACHAL PRADESH  2009  18.0   92.8   72.1  132.7  189.9
#
#        JUN     JUL    AUG    SEP    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
data2=data.drop(['ANNUAL','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec'],axis=1)

# %%
data2
# Out:
#     Unnamed: 0        SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0          110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6
# 1          111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9
# 2          112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1
# 3          113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6
# 4          114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6
# ..         ...                ...   ...   ...    ...    ...    ...    ...
# 86         196  ARUNACHAL PRADESH  2005  48.4  167.6  229.5  195.3  179.8
# 87         197  ARUNACHAL PRADESH  2006   6.0  103.7   63.3  202.7  321.7
# 88         198  ARUNACHAL PRADESH  2007  13.4   97.4   48.1  292.4  250.4
# 89         199  ARUNACHAL PRADESH  2008  76.7   39.7  122.6  192.4  185.0
# 90         200  ARUNACHAL PRADESH  2009  18.0   92.8   72.1  132.7  189.9
#
#        JUN     JUL    AUG    SEP    OCT   NOV   DEC
# ...

# %%
data1['SUBDIVISION'].unique()
# Out:
# array(['ARUNACHAL PRADESH'], dtype=object)

# %%
data2=data.loc[(data1.SUBDIVISION=='ARUNACHAL PRADESH')]

# %%
data2
# Out:
#     Unnamed: 0        SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0          110  ARUNACHAL PRADESH  1916  48.1   69.8   71.1  316.1  424.6
# 1          111  ARUNACHAL PRADESH  1917  21.4  164.5    NaN  269.6  107.9
# 2          112  ARUNACHAL PRADESH  1918  10.4   11.0  191.2  144.6  861.1
# 3          113  ARUNACHAL PRADESH  1919  34.5   67.8   28.5  256.9  420.6
# 4          114  ARUNACHAL PRADESH  1920  14.0  196.3  605.6  364.7  173.6
# ..         ...                ...   ...   ...    ...    ...    ...    ...
# 86         196  ARUNACHAL PRADESH  2005  48.4  167.6  229.5  195.3  179.8
# 87         197  ARUNACHAL PRADESH  2006   6.0  103.7   63.3  202.7  321.7
# 88         198  ARUNACHAL PRADESH  2007  13.4   97.4   48.1  292.4  250.4
# 89         199  ARUNACHAL PRADESH  2008  76.7   39.7  122.6  192.4  185.0
# 90         200  ARUNACHAL PRADESH  2009  18.0   92.8   72.1  132.7  189.9
#
#        JUN     JUL    AUG    SEP    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
data2.isna().sum()
# Out:
# Unnamed: 0     0
# SUBDIVISION    0
# YEAR           0
# JAN            1
# FEB            1
# MAR            2
# APR            0
# MAY            0
# JUN            1
# JUL            1
# AUG            0
# SEP            0
# OCT            2
# NOV            2
# DEC            2
# ANNUAL         6
# Jan-Feb        1
# Mar-May        2
# Jun-Sep        2
# Oct-Dec        3
# dtype: int64

# %%
data2=data.fillna(data2.mean())
data2
# Out:
#     Unnamed: 0        SUBDIVISION  YEAR   JAN    FEB         MAR    APR  \
# 0          110  ARUNACHAL PRADESH  1916  48.1   69.8   71.100000  316.1
# 1          111  ARUNACHAL PRADESH  1917  21.4  164.5  154.446067  269.6
# 2          112  ARUNACHAL PRADESH  1918  10.4   11.0  191.200000  144.6
# 3          113  ARUNACHAL PRADESH  1919  34.5   67.8   28.500000  256.9
# 4          114  ARUNACHAL PRADESH  1920  14.0  196.3  605.600000  364.7
# ..         ...                ...   ...   ...    ...         ...    ...
# 86         196  ARUNACHAL PRADESH  2005  48.4  167.6  229.500000  195.3
# 87         197  ARUNACHAL PRADESH  2006   6.0  103.7   63.300000  202.7
# 88         198  ARUNACHAL PRADESH  2007  13.4   97.4   48.100000  292.4
# 89         199  ARUNACHAL PRADESH  2008  76.7   39.7  122.600000  192.4
# 90         200  ARUNACHAL PRADESH  2009  18.0   92.8   72.100000  132.7
#
#       MAY     JUN          JUL    AUG    SEP         OCT        NOV  \
# ...

# %%
data2['ANNUAL RAIN']=data.apply(lambda row:row.JAN+row.FEB,axis=1)

# %%
data2
# Out:
#     Unnamed: 0        SUBDIVISION  YEAR   JAN    FEB         MAR    APR  \
# 0          110  ARUNACHAL PRADESH  1916  48.1   69.8   71.100000  316.1
# 1          111  ARUNACHAL PRADESH  1917  21.4  164.5  154.446067  269.6
# 2          112  ARUNACHAL PRADESH  1918  10.4   11.0  191.200000  144.6
# 3          113  ARUNACHAL PRADESH  1919  34.5   67.8   28.500000  256.9
# 4          114  ARUNACHAL PRADESH  1920  14.0  196.3  605.600000  364.7
# ..         ...                ...   ...   ...    ...         ...    ...
# 86         196  ARUNACHAL PRADESH  2005  48.4  167.6  229.500000  195.3
# 87         197  ARUNACHAL PRADESH  2006   6.0  103.7   63.300000  202.7
# 88         198  ARUNACHAL PRADESH  2007  13.4   97.4   48.100000  292.4
# 89         199  ARUNACHAL PRADESH  2008  76.7   39.7  122.600000  192.4
# 90         200  ARUNACHAL PRADESH  2009  18.0   92.8   72.100000  132.7
#
#       MAY     JUN          JUL  ...    SEP         OCT        NOV        DEC  \
# ...

# %%
cor=data.corr()
cor
# Out:
#             Unnamed: 0      YEAR       JAN       FEB       MAR       APR  \
# Unnamed: 0    1.000000  0.999610 -0.130520 -0.134521 -0.146730 -0.293626
# YEAR          0.999610  1.000000 -0.129778 -0.134399 -0.153629 -0.301073
# JAN          -0.130520 -0.129778  1.000000  0.049703  0.102652  0.275465
# FEB          -0.134521 -0.134399  0.049703  1.000000  0.346448  0.268504
# MAR          -0.146730 -0.153629  0.102652  0.346448  1.000000  0.292072
# APR          -0.293626 -0.301073  0.275465  0.268504  0.292072  1.000000
# MAY          -0.381310 -0.384602  0.213443 -0.063280  0.017182  0.114128
# JUN          -0.629492 -0.630502  0.187899  0.084133  0.110014  0.293255
# JUL          -0.464201 -0.465649  0.036231  0.102494  0.038299  0.252243
# AUG          -0.397151 -0.394444  0.186397  0.028861  0.068542  0.157620
# SEP          -0.429514 -0.431541  0.180209  0.168561  0.052330  0.176335
# OCT          -0.295578 -0.294323  0.144752 -0.054956 -0.149850  0.046071
# ...

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidth=.5,cmap='bwr')
# Out:
# <Axes: >

# %%
data1=data1.drop(['SUBDIVISION','JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','ANNUAL'],axis=1)

# %%
data2
# Out:
#     Unnamed: 0  YEAR         MAR    APR    MAY     JUN          JUL    AUG  \
# 0          110  1916   71.100000  316.1  424.6  1124.9   710.656044  629.7
# 1          111  1917  154.446067  269.6  107.9   823.8   909.100000  628.4
# 2          112  1918  191.200000  144.6  861.1  1609.9  1303.000000  692.6
# 3          113  1919   28.500000  256.9  420.6   973.6   999.000000  286.7
# 4          114  1920  605.600000  364.7  173.6   840.6   535.400000  896.5
# ..         ...   ...         ...    ...    ...     ...          ...    ...
# 86         196  2005  229.500000  195.3  179.8   269.3   430.800000  400.0
# 87         197  2006   63.300000  202.7  321.7   520.4   382.200000  227.6
# 88         198  2007   48.100000  292.4  250.4   530.2   761.000000  364.6
# 89         199  2008  122.600000  192.4  185.0   423.6   456.100000  439.3
# 90         200  2009   72.100000  132.7  189.9   259.1   329.900000  370.3
#
# ...

# %%
cor=data2.corr()
cor
# Out:
#              Unnamed: 0      YEAR       MAR       APR       MAY       JUN  \
# Unnamed: 0     1.000000  0.999610 -0.144357 -0.293626 -0.381310 -0.628853
# YEAR           0.999610  1.000000 -0.151211 -0.301073 -0.384602 -0.629724
# MAR           -0.144357 -0.151211  1.000000  0.292034  0.016967  0.109600
# APR           -0.293626 -0.301073  0.292034  1.000000  0.114128  0.289778
# MAY           -0.381310 -0.384602  0.016967  0.114128  1.000000  0.393296
# JUN           -0.628853 -0.629724  0.109600  0.289778  0.393296  1.000000
# JUL           -0.456500 -0.458067  0.037387  0.251912  0.506657  0.521135
# AUG           -0.397151 -0.394444  0.068452  0.157620  0.363992  0.415872
# SEP           -0.429514 -0.431541  0.052290  0.176335  0.258744  0.346845
# OCT           -0.290304 -0.289099 -0.148228  0.045964  0.127813  0.192219
# NOV           -0.075613 -0.076111 -0.063092  0.288564  0.031010  0.109060
# DEC           -0.047054 -0.048522  0.064708  0.337172  0.089021  0.038574
# ...

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidth=.5,cmap='bwr')
# Out:
# <Axes: >
